# %%
# !pip install tensorflow-io
# Out:
# Collecting tensorflow-io
#   Downloading tensorflow_io-0.22.0-cp39-cp39-macosx_10_14_x86_64.whl (22.8 MB)
#      |████████████████████████████████| 22.8 MB 3.9 MB/s
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.22.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow-io) (0.22.0)
# Requirement already satisfied: tensorflow<2.8.0,>=2.7.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow-io) (2.7.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (1.1.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (1.6.3)
# Requirement already satisfied: tensorboard~=2.6 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (2.7.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (1.41.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (2.7.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (3.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (1.13.3)
# Requirement already satisfied: libclang>=9.0.1 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (12.0.0)
# Requirement already satisfied: absl-py>=0.4.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (0.15.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (0.37.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (2.7.0)
# Requirement already satisfied: six>=1.12.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (1.16.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (3.19.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (3.10.0.2)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (1.1.2)
# Requirement already satisfied: numpy>=1.14.5 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorflow<2.8.0,>=2.7.0->tensorflow-io) (1.21.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (58.0.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (2.26.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (2.3.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (0.4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (1.26.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/stephen/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<2.8.0,>=2.7.0->tensorflow-io) (3.1.1)
# Installing collected packages: tensorflow-io
# Successfully installed tensorflow-io-0.22.0

# %%
import os
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
import tensorflow as tf
import tensorflow_io as tfio

from tensorflow.keras import layers
from tensorflow.keras import models
from IPython import display

# Set the seed value for experiment reproducibility.
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
df = pd.read_csv('/Users/stephen/Emotion_Dectection/data/RAVDESS/metadata.csv', index_col=0)
df.head()
# Out:
#                                                       modality vocal_channel  \
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  audio_only        speech
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  audio_only        speech
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  audio_only        speech
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  audio_only        speech
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  audio_only        speech
#
#                                                       emotion  \
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  surprised
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  surprised
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...      angry
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...    fearful
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...    fearful
#
#                                                    emotional_intensity  \
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...              strong
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...              normal
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...              normal
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...              normal
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...              strong
#
#                                                                        statement  \
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  Dogs are sitting by the door
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  Kids are talking by the door
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  Dogs are sitting by the door
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  Dogs are sitting by the door
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  Kids are talking by the door
#
#                                                            repetition  actor  \
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...   first_repitition      1
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...   first_repitition      1
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...   first_repitition      1
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  second_repetition      1
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  second_repetition      1
#
#                                                    actor_sex
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...      male
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...      male
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...      male
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...      male
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...      male

# %%
df.drop(columns=['modality', 'vocal_channel', 'emotional_intensity', 'statement', 'repetition', 'actor', 'actor_sex'], inplace=True)
df
# Out:
#                                                       emotion
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  surprised
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...  surprised
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...      angry
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...    fearful
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...    fearful
# ...                                                       ...
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...      happy
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...      happy
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...       calm
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...       calm
# /Users/stephen/Emotion_Dectection/data/RAVDESS/...    neutral
#
# [1380 rows x 1 columns]

# %%
test_file = tf.io.read_file('/Users/stephen/Emotion_Dectection/data/RAVDESS/Audio_Speech_Actors_01-24/Actor_04/03-01-01-01-02-01-04.wav')
test_audio, _ = tf.audio.decode_wav(contents=test_file)
test_audio.shape
# Out:
# 2021-11-30 22:37:49.077879: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at decode_wav_op.cc:55 : INVALID_ARGUMENT: Data too short when trying to read string
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /var/folders/m3/ywsrz7k170vbk8511l1h_6840000gn/T/ipykernel_63578/4134909272.py in <module>
#       1 test_file = tf.io.read_file('/Users/stephen/Emotion_Dectection/data/RAVDESS/Audio_Speech_Actors_01-24/Actor_04/03-01-01-01-02-01-04.wav')
# ----> 2 test_audio, _ = tf.audio.decode_wav(contents=test_file)
#       3 test_audio.shape
#
# ~/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages/tensorflow/python/ops/gen_audio_ops.py in decode_wav(contents, desired_channels, desired_samples, name)
#     177       return _result
#     178     except _core._NotOkStatusException as e:
# --> 179       _ops.raise_from_not_ok_status(e, name)
#     180     except _core._FallbackException:
#     181       pass
#
# ~/opt/anaconda3/envs/torch_env/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    7105 def raise_from_not_ok_status(e, name):
#    7106   e.message += (" name: " + name if name is not None else "")
# -> 7107   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    7108
#    7109
#
# InvalidArgumentError: Data too short when trying to read string [Op:DecodeWav]
